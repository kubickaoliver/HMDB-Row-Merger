# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/hmdb_synonyma_test.csv', delimiter='#')
df.head()
# Out:
#             drug_name                                         Unnamed: 1
# 0              biotin                                             biotin  \
# 1   1-methylhistidine  (2s)-2-amino-3-(1-methyl-1h-imidazol-4-yl)prop...
# 2  1,3-diaminopropane                                 1,3-propanediamine
# 3              biotin                                             biotin
# 4  2-ketobutyric acid                                2-ketobutanoic acid
#
#                                           Unnamed: 2             Unnamed: 3
# 0                                             biotin                 biotin  \
# 1  (2s)-2-amino-3-(1-methyl-1h-imidazol-4-yl)prop...      1 methylhistidine
# 2                               1,3-propylenediamine    propane-1,3-diamine
# 3                                             biotin                 biotin
# 4                                  2-oxobutyric acid  3-methyl pyruvic acid
#
#                                           Unnamed: 4
# 0  (+)-cis-hexahydro-2-oxo-1h-thieno[3,4]imidazol...  \
# 1                                 1-methyl histidine
# 2                                                 tn
# 3  (+)-cis-hexahydro-2-oxo-1h-thieno[3,4]imidazol...
# 4                                 alpha-ketobutyrate
#
#                                           Unnamed: 5
# 0  (3as,4s,6ar)-hexahydro-2-oxo-1h-thieno[3,4-d]i...  \
# 1                                 1-methyl-histidine
# 2                                trimethylenediamine
# 3  (3as,4s,6ar)-hexahydro-2-oxo-1h-thieno[3,4-d]i...
# 4                             alpha-ketobutyric acid
#
#                                           Unnamed: 6
# 0  5-(2-oxohexahydro-1h-thieno[3,4-d]imidazol-4-y...  \
# 1                               1-methyl-l-histidine
# 2                                 1,3-diaminepropane
# 3  5-(2-oxohexahydro-1h-thieno[3,4-d]imidazol-4-y...
# 4                           alpha-oxo-n-butyric acid
#
#                             Unnamed: 7                         Unnamed: 8
# 0                              biotina                            biotine  \
# 1                               1-mhis             1-n-methyl-l-histidine
# 2  trimethylenediamine dihydrochloride  trimethylenediamine hydrochloride
# 3                              biotina                            biotine
# 4                        2-oxobutyrate                 2-oxobutanoic acid
#
#               Unnamed: 9  ... Unnamed: 163 Unnamed: 164 Unnamed: 165
# 0               biotinum  ...          NaN          NaN          NaN  \
# 1    l-1-methylhistidine  ...          NaN          NaN          NaN
# 2  1,3-diamino-n-propane  ...          NaN          NaN          NaN
# 3               biotinum  ...          NaN          NaN          NaN
# 4        2-ketobutanoate  ...          NaN          NaN          NaN
#
#   Unnamed: 166 Unnamed: 167 Unnamed: 168 Unnamed: 169 Unnamed: 170
# 0          NaN          NaN          NaN          NaN          NaN  \
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 171 Unnamed: 172
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 173 columns]

# %%
chemicals_rows = {}

for index, row in df.iterrows():
    for column in df.columns:
        if isinstance(row[column], str):
            if chemicals_rows.get(row[column]):
                if index not in chemicals_rows[row[column]]:
                    chemicals_rows[row[column]].append(index)
            else:
                chemicals_rows[row[column]] = [index]

rows_to_concat = {}
for _, row_list in chemicals_rows.items():
    main_row = row_list[0]

    parent = None
    for index, row in enumerate(row_list):
        if rows_to_concat.get(row) and isinstance(rows_to_concat[row], int):
            parent = rows_to_concat[row]
            break
    
    if parent:
        rows_to_concat[parent] = list(set(rows_to_concat[parent]).union(set(row_list)))
    else:
        if not rows_to_concat.get(main_row) and len(row_list) > 1:
            rows_to_concat[main_row] = row_list

    # Define which key point to which key
    for index, row in enumerate(row_list):
        if not rows_to_concat.get(row):
            if parent:
                rows_to_concat[row] = parent
            elif row != main_row:
                rows_to_concat[row] = main_row

for key, value in rows_to_concat.items():
    print({key: value})
# Out:
# {0: [0, 3]}
# {3: 0}
# {6: [6, 7, 8, 9, 10, 11]}
# {8: 6}
# {11: 6}
# {7: 6}
# {9: 6}
# {10: 6}
